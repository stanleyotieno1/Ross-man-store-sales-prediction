# %%
# %pip install scikit-learn --upgrade --quite
# Out:
# Usage:
#   /home/stanley-otieno/Machine-Learning/weather-prediction/jovian/bin/python -m pip install [options] <requirement specifier> [package-index-options] ...
#   /home/stanley-otieno/Machine-Learning/weather-prediction/jovian/bin/python -m pip install [options] -r <requirements file> [package-index-options] ...
#   /home/stanley-otieno/Machine-Learning/weather-prediction/jovian/bin/python -m pip install [options] [-e] <vcs project url> ...
#   /home/stanley-otieno/Machine-Learning/weather-prediction/jovian/bin/python -m pip install [options] [-e] <local project path> ...
#   /home/stanley-otieno/Machine-Learning/weather-prediction/jovian/bin/python -m pip install [options] <archive url/path> ...
#
# no such option: --quite
# Note: you may need to restart the kernel to use updated packages.
